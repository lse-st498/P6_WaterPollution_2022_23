# %%
import pandas as pd
import numpy as np

# %%
sites_data_1 = pd.read_csv("~data/sites_data_s2_grid_index_update_1.csv")
sites_data_2 = pd.read_csv("~data/sites_data_s2_grid_index_update_2.csv")
sites_data_3 = pd.read_csv("~data/sites_data_s2_grid_index_update_3.csv")
sites_data_4 = pd.read_csv("~data/sites_data_s2_grid_index_update_4.csv")
sites_data_5 = pd.read_csv("~data/sites_data_s2_grid_index_update_5.csv")

# %%
pd_list = [sites_data_1, sites_data_2, sites_data_3, sites_data_4, sites_data_5]
sites_data = pd.concat(pd_list)

# %%
sites_data
# Out:
#           Unnamed: 0.1  Unnamed: 0        time        lat       lon
# 0                    0           0  2020-01-04  52.655093  1.733927  \
# 1                    1           1  2020-01-04  52.655093  1.735674
# 2                    2           2  2020-01-04  52.655093  1.737421
# 3                    3           3  2020-01-04  52.655093  1.739168
# 4                    4           4  2020-01-04  52.655093  1.740915
# ...                ...         ...         ...        ...       ...
# 24225833     134225833   134225833  2022-12-29  52.546759  1.770615
# 24225834     134225834   134225834  2022-12-29  52.546759  1.772362
# 24225835     134225835   134225835  2022-12-29  52.546759  1.774109
# 24225836     134225836   134225836  2022-12-29  52.546759  1.775856
# 24225837     134225837   134225837  2022-12-29  52.546759  1.777603
#
#                 TUR        SPM        CHL           site  grid_index
# 0         75.791490  57.119390  10.334003  ukh1303-10400        2571  \
# ...

# %%
sites_data.to_csv('~data/sites_data_s2_grid_index_updated.csv')
