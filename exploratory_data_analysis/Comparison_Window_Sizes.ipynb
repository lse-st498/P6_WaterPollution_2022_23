# %%
import matplotlib.pyplot as plt

# %%
window_sizes_S2 = ['1x1', '3x3', '5x5', '7x7', '9x9']

LR_S2 = [0.0767846430713857, 0.0821699242122058, 0.0962621607782898, 0.0895674300254452, 0.0941541645111226]
RF_S2 = [0.007366, 0.012927, 0.02011, 0.020165, 0.020055]
MLP_S2 = [0.0881417537482962, 0.0812337098175499, 0.0815673730507796, 0.0724384432088959, 0.0755417956656346]
CNN_S2 = [0.0419916734099388, 0.0996, 0.040139228105545, 0.0536066964268684, 0.0660982355475425]

plt.figure(figsize=(8, 6))
plt.plot(window_sizes_S2, LR_S2, marker='o', label='LR')
plt.plot(window_sizes_S2, RF_S2, marker='o', label='RF')
plt.plot(window_sizes_S2, MLP_S2, marker='o', label='MLP')
plt.plot(window_sizes_S2, CNN_S2, marker='o', label='CNN')

baseline = 0.024
plt.axhline(y=baseline, color='gray', linestyle='--', label="Baseline")

plt.xlabel('Window Sizes')
plt.ylabel('F1 Score')
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.09), ncol=5)
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()
plt.show()

# %%
# %matplotlib inline
window_sizes_S3 = ['1x1', '3x3', '5x5', '7x7', '9x9', '11x11', '13x13', '15x15']

LR_S3 = [0.0915634897782896, 0.0933940774487471, 0.091816367265469, 0.0924822695035461, 0.0927717700626067, 0.0932878270762229, 0.0931289040318001, 0.0923774440351374]
RF_S3 = [0.086205, 0.085861, 0.086072, 0.085892, 0.085735, 0.085907, 0.085892, 0.085869]
CNN_S3 = [0.0904480591416359, 0.0873342156410217, 0.0870311483740806, 0.0888533219695091, 0.0905974134802818, 0.0879897102713584, 0.0889284163713455, 0.0896776989102363]
MLP_S3 = [0.0907859078590785, 0.0941232680363115, 0.0990899898887765, 0.0864779874213836, 0.0943043884220354, 0.0937866354044548, 0.085775276537939, 0.0905172413793103]

fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True, figsize=(8, 6), gridspec_kw={'height_ratios': [3, 1]})
fig.subplots_adjust(hspace=0.05)

baseline = 0.025
highest = max(LR_S3+RF_S3+MLP_S3+CNN_S3)
lowest = min(LR_S3+RF_S3+MLP_S3+CNN_S3)
unit = (highest - lowest)/2

for data, label in zip([LR_S3, RF_S3, MLP_S3, CNN_S3], ["LR", "RF", "MLP", "CNN"]):

    ax1.plot(window_sizes_S3, data, label=label, marker='o')
    ax2.plot(window_sizes_S3, data, marker='o')

ax1.axhline(y=baseline, color='gray', linestyle='--', label="Baseline")
ax2.axhline(y=baseline, color='gray', linestyle='--')

ax1.set_ylim(lowest-0.5*unit, highest+0.5*unit) 
ax2.set_ylim(baseline-0.5*unit, baseline+0.5*unit) 

ax1.spines['bottom'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax1.xaxis.tick_top()
ax1.tick_params(labeltop=False)
ax2.xaxis.tick_bottom()

d = .01  
kwargs = dict(transform=ax1.transAxes, color='k', clip_on=False)
ax1.plot((-d, +d), (-d, +d), **kwargs)
ax1.plot((1 - d, 1 + d), (-d, +d), **kwargs)
kwargs.update(transform=ax2.transAxes)
ax2.plot((-d, +d), (1 - d, 1 + d), **kwargs)
ax2.plot((1 - d, 1 + d), (1 - d, 1 + d), **kwargs)
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
ax2.grid(True, which='both', linestyle='--', linewidth=0.5)


ax1.legend(loc='upper center', bbox_to_anchor=(0.5, 1.1), ncol=5)
ax2.set_xlabel("Window Sizes")
plt.tight_layout()
plt.show()
